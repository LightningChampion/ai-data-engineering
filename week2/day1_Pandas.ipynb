# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.12/dist-packages/pandas/__init__.py'>

# %%
data = {
    "product":["laptop","mouse", "desk"],
    "category": ["technology","technology","furniture"],
    "price":[30000,500,4000]

}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   product    category  price
# 0  laptop  technology  30000
# 1   mouse  technology    500
# 2    desk   furniture   4000

# %%
df.head()
# Out:
#   product    category  price
# 0  laptop  technology  30000
# 1   mouse  technology    500
# 2    desk   furniture   4000

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['product', 'category', 'price'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   product   3 non-null      object
#  1   category  3 non-null      object
#  2   price     3 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#               price
# count      3.000000
# mean   11500.000000
# std    16116.761461
# min      500.000000
# 25%     2250.000000
# 50%     4000.000000
# 75%    17000.000000
# max    30000.000000

# %%
df.isnull()
# Out:
#    product  category  price
# 0    False     False  False
# 1    False     False  False
# 2    False     False  False

# %%
df.isnull().sum()
# Out:
# product     0
# category    0
# price       0
# dtype: int64

# %%
df["price"]
# Out:
# 0    30000
# 1      500
# 2     4000
# Name: price, dtype: int64

# %%
df["price"].mean()
# Out:
# np.float64(11500.0)

# %%
df["price"].sum()
# Out:
# np.int64(34500)

# %%
print(df["price"].sum())
# Out:
# 34500

# %%
df["price"].max()
# Out:
# 30000

# %%
df["price"].median()
# Out:
# 4000.0

# %%
df["price"].min()
# Out:
# 500

# %%
df [df["category"] == "technology"]
# Out:
#   product    category  price
# 0  laptop  technology  30000
# 1   mouse  technology    500

# %%
df[df["price"] > 1000]
# Out:
#   product    category  price
# 0  laptop  technology  30000
# 2    desk   furniture   4000

# %%
df [(df["category"] == "technology") & (df["price"] >1000)]
# Out:
#   product    category  price
# 0  laptop  technology  30000

# %%
df.sort_values("price")
# Out:
#   product    category  price
# 1   mouse  technology    500
# 2    desk   furniture   4000
# 0  laptop  technology  30000

# %%
df.sort_values("price", ascending= False)
# Out:
#   product    category  price
# 0  laptop  technology  30000
# 2    desk   furniture   4000
# 1   mouse  technology    500

# %%
df["category"].value_counts()
# Out:
# category
# technology    2
# furniture     1
# Name: count, dtype: int64

# %%
df.groupby("category")["price"].mean()
# Out:
# category
# furniture      4000.0
# technology    15250.0
# Name: price, dtype: float64

# %%
df.groupby("category")["price"].sum()
# Out:
# category
# furniture      4000
# technology    30500
# Name: price, dtype: int64

# %%
df.groupby("category")["price"].agg(["sum","mean","max","min"])
# Out:
#               sum     mean    max   min
# category
# furniture    4000   4000.0   4000  4000
# technology  30500  15250.0  30000   500

# %%
csv_data = """product,category,price
laptop,technology,30000
mouse,technology,500
desk,furniture,4000
chair,furniture,2500
"""

with open("products.csv", "w") as file:
  file.write(csv_data)

# %%
df_csv = pd.read_csv("products.csv")
df_csv
# Out:
#   product    category  price
# 0  laptop  technology  30000
# 1   mouse  technology    500
# 2    desk   furniture   4000
# 3   chair   furniture   2500

# %%
df_csv.head()
# Out:
#   product    category  price
# 0  laptop  technology  30000
# 1   mouse  technology    500
# 2    desk   furniture   4000
# 3   chair   furniture   2500

# %%
df_csv.shape
# Out:
# (4, 3)

# %%
df_csv.columns
# Out:
# Index(['product', 'category', 'price'], dtype='object')

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   product   4 non-null      object
#  1   category  4 non-null      object
#  2   price     4 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df_csv.describe()
# Out:
#               price
# count      4.000000
# mean    9250.000000
# std    13907.432066
# min      500.000000
# 25%     2000.000000
# 50%     3250.000000
# 75%    10500.000000
# max    30000.000000

# %%
df_csv.isnull().sum()
# Out:
# product     0
# category    0
# price       0
# dtype: int64
